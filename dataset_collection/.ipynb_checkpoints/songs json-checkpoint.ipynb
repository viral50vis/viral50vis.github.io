# %%
import os
import pandas as pd

# %%
masterlist_path = '../data/song_masterlist.csv'
base = '../data/countries/'

# %%
songs = pd.read_csv(masterlist_path)

# %%
songs.head()
# Out:
#                                           Track Name          Artist  \
# 0                                      Weź nie pytaj  Paweł Domagała
# 1  Wszystko czego dziś chcę (z serialu Rojst na S...          Brodka
# 2                                    Grube Koleżanki           Guova
# 3                                         Baby Shark        Pinkfong
# 4                           Bella ciao - HUGEL Remix     El Profesor
#
#                                                  URL  danceability  energy  \
# 0  https://open.spotify.com/track/4WgOhIHX0Ez6vJ7...         0.508   0.517
# 1  https://open.spotify.com/track/0FoR0PrLkw6t64w...         0.629   0.840
# 2  https://open.spotify.com/track/1H9x1qTmqMYum9U...         0.779   0.683
# 3  https://open.spotify.com/track/5ygDXis42ncn6kY...         0.829   0.886
# 4  https://open.spotify.com/track/1MFSD0AkPk8Yq7T...         0.838   0.406
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    7    -6.632     1       0.0419      0.149000          0.000000    0.1900
# 1   10    -7.991     0       0.0267      0.000356          0.057000    0.6660
# 2    6    -7.399     1       0.0645      0.403000          0.000875    0.1030
# 3    8    -1.746     1       0.1120      0.259000          0.000000    0.0559
# 4   11   -11.833     0       0.0878      0.196000          0.004710    0.1010
#
#    valence    tempo  duration_ms  time_signature
# 0    0.595  104.065       260992               3
# 1    0.367   93.990       359404               4
# 2    0.670  105.010       176000               4
# 3    0.777  115.056        80927               4
# 4    0.655  126.020       165533               4

# %%
masterblaster = {}

for directory in os.listdir(base):
    if directory == ".DS_Store":
        continue
    path = base + directory + '/'
    for filename in os.listdir(path):
        temp = pd.read_csv(path+filename)
        date = filename.split('_')[1]
        date = date.split('.')[0]
        
        week = {}
        temp.iloc()
        
        if date in masterblaster:
            x = 1
        else:
            x = 1
        break
    break
# Out:
# 2017-01-12
