# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '../data/week_mean/0.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#     CC  acousticness  danceability    energy  instrumentalness   key  \
# 0  POL      0.236699       0.73096  0.648280          0.017771  6.18
# 1  HND      0.233088       0.74478  0.665620          0.016362  5.28
# 2  SWE      0.260022       0.68436  0.572140          0.063888  5.86
# 3  NOR      0.274756       0.70808  0.608776          0.068855  5.62
# 4  LUX      0.318533       0.73170  0.594760          0.025837  6.28
#
#    liveness  loudness  mode  speechiness      tempo  time_signature   valence
# 0  0.163238  -7.34862  0.56     0.146254  122.70676            3.98  0.524376
# 1  0.184588  -5.18690  0.54     0.133042  124.95646            3.98  0.610900
# 2  0.164594  -8.43324  0.66     0.143618  122.20654            3.90  0.532662
# 3  0.174572  -7.93262  0.60     0.126276  119.94822            3.98  0.526048
# 4  0.157138  -7.15714  0.48     0.133126  120.53902            3.98  0.473030

# %%
df.corr()
# Out:
#                   acousticness  danceability    energy  instrumentalness  \
# acousticness          1.000000     -0.667838 -0.671454         -0.075263
# danceability         -0.667838      1.000000  0.488833          0.028278
# energy               -0.671454      0.488833  1.000000         -0.166081
# instrumentalness     -0.075263      0.028278 -0.166081          1.000000
# key                   0.144148     -0.181123 -0.157658          0.089898
# liveness             -0.160380      0.059045  0.333012         -0.056145
# loudness             -0.474339      0.477168  0.806685         -0.452918
# mode                  0.137902     -0.315329 -0.142512          0.021837
# speechiness          -0.559796      0.687765  0.372446          0.152927
# tempo                -0.266405      0.159752  0.484882         -0.168899
# time_signature       -0.064021      0.067642  0.088186         -0.372360
# valence              -0.484699      0.612449  0.809537         -0.252831
#
# ...

# %%
sns.heatmap(df.corr())
plt.savefig('heatmap.png')
